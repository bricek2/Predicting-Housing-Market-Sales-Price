# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.impute import SimpleImputer

from sklearn.preprocessing import OneHotEncoder

# %%
train_clean = pd.read_csv('../datasets/train_clean.csv')
test_clean = pd.read_csv('../datasets/test_clean.csv')

# %% [markdown]
# ## Preproccessing Categorical Features

# %%
explore = [
    'neighborhood', 
    'paved_drive',
    'gr_liv_area',
    'overall_qual',
    'garage_area',
    'total_bsmt_sf',
    'year_built',
    'year_remod_add',
    'mas_vnr_area',
    'fireplaces',
    'bsmtfin_sf_1',
    'central_air']

# %%
def null_type(lis):
    return train_clean.isnull().sum()[lis], train_clean.dtypes[lis]

# %%
null_type(explore)
# Out:
# (neighborhood      0
#  paved_drive       0
#  gr_liv_area       0
#  overall_qual      0
#  garage_area       0
#  total_bsmt_sf     0
#  year_built        0
#  year_remod_add    0
#  mas_vnr_area      0
#  fireplaces        0
#  bsmtfin_sf_1      0
#  central_air       0
#  dtype: int64,
#  neighborhood       object
#  paved_drive        object
#  gr_liv_area       float64
#  overall_qual        int64
#  garage_area       float64
#  total_bsmt_sf     float64
#  year_built          int64
#  year_remod_add      int64
#  mas_vnr_area      float64
#  fireplaces          int64
#  bsmtfin_sf_1      float64
#  central_air         int64
#  dtype: object)

# %%
test_clean.isnull().sum()[explore], test_clean.dtypes[explore]
# Out:
# (neighborhood      0
#  paved_drive       0
#  gr_liv_area       0
#  overall_qual      0
#  garage_area       0
#  total_bsmt_sf     0
#  year_built        0
#  year_remod_add    0
#  mas_vnr_area      0
#  fireplaces        0
#  bsmtfin_sf_1      0
#  central_air       0
#  dtype: int64,
#  neighborhood       object
#  paved_drive        object
#  gr_liv_area       float64
#  overall_qual        int64
#  garage_area       float64
#  total_bsmt_sf     float64
#  year_built          int64
#  year_remod_add      int64
#  mas_vnr_area      float64
#  fireplaces          int64
#  bsmtfin_sf_1      float64
#  central_air         int64
#  dtype: object)

# %%
train_clean['paved_drive'].unique()
# Out:
# array(['Y', 'N', 'P'], dtype=object)

# %%
test_clean['paved_drive'].unique()
# Out:
# array(['Y', 'N', 'P'], dtype=object)

# %% [markdown]
# ### Set up a train and test split to preprocess categorical data

# %%
X = train_clean[explore]
y = train_clean['saleprice']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 6, train_size = .8)

# %% [markdown]
# - Convert Paved Driveway to ordinal values

# %%
driveway_dict = {
    'Y': 2,
    'P': 1,
    'N': 0,
}

# %%
X_train['paved_drive'] = X_train['paved_drive'].map(driveway_dict)
X_test['paved_drive'] = X_test['paved_drive'].map(driveway_dict)

# %%
X_train['paved_drive'].dtypes
# Out:
# dtype('int64')

# %%
one_hot = OneHotEncoder(handle_unknown='ignore')
one_hot.fit(X_train[['neighborhood']])
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
one_hot.get_feature_names_out()
# Out:
# array(['neighborhood_Blmngtn', 'neighborhood_Blueste',
#        'neighborhood_BrDale', 'neighborhood_BrkSide',
#        'neighborhood_ClearCr', 'neighborhood_CollgCr',
#        'neighborhood_Crawfor', 'neighborhood_Edwards',
#        'neighborhood_Gilbert', 'neighborhood_Greens',
#        'neighborhood_GrnHill', 'neighborhood_IDOTRR',
#        'neighborhood_Landmrk', 'neighborhood_MeadowV',
#        'neighborhood_Mitchel', 'neighborhood_NAmes',
#        'neighborhood_NPkVill', 'neighborhood_NWAmes',
#        'neighborhood_NoRidge', 'neighborhood_NridgHt',
#        'neighborhood_OldTown', 'neighborhood_SWISU',
#        'neighborhood_Sawyer', 'neighborhood_SawyerW',
#        'neighborhood_Somerst', 'neighborhood_StoneBr',
#        'neighborhood_Timber', 'neighborhood_Veenker'], dtype=object)

# %%
train_one_hot = pd.DataFrame(
    one_hot.transform(X_train[['neighborhood']]).todense(),
    columns = one_hot.get_feature_names_out(),
    index = X_train.index
)

train_one_hot.head(1)
# Out:
#      neighborhood_Blmngtn  neighborhood_Blueste  neighborhood_BrDale  \
# 459                   0.0                   0.0                  0.0
#
#      neighborhood_BrkSide  neighborhood_ClearCr  neighborhood_CollgCr  \
# 459                   0.0                   0.0                   0.0
#
#      neighborhood_Crawfor  neighborhood_Edwards  neighborhood_Gilbert  \
# 459                   0.0                   0.0                   0.0
#
#      neighborhood_Greens  ...  neighborhood_NoRidge  neighborhood_NridgHt  \
# 459                  0.0  ...                   0.0                   0.0
#
#      neighborhood_OldTown  neighborhood_SWISU  neighborhood_Sawyer  \
# 459                   0.0                 1.0                  0.0
#
#      neighborhood_SawyerW  neighborhood_Somerst  neighborhood_StoneBr  \
# 459                   0.0                   0.0                   0.0
#
#      neighborhood_Timber  neighborhood_Veenker
# 459                  0.0                   0.0
#
# [1 rows x 28 columns]

# %%
test_one_hot = pd.DataFrame(
    one_hot.transform(X_test[['neighborhood']]).todense(),
    columns = one_hot.get_feature_names_out(),
    index = X_test.index
)

# %%
X_train = pd.concat(
    [X_train.drop(columns=['neighborhood']), train_one_hot],
    axis=1
)

X_train.head(1)
# Out:
#      paved_drive  gr_liv_area  overall_qual  garage_area  total_bsmt_sf  \
# 459            2       1551.0             5        240.0         1058.0
#
#      year_built  year_remod_add  mas_vnr_area  fireplaces  bsmtfin_sf_1  ...  \
# 459        1938            1950           0.0           0         930.0  ...
#
#      neighborhood_NoRidge  neighborhood_NridgHt  neighborhood_OldTown  \
# 459                   0.0                   0.0                   0.0
#
#      neighborhood_SWISU  neighborhood_Sawyer  neighborhood_SawyerW  \
# 459                 1.0                  0.0                   0.0
#
#      neighborhood_Somerst  neighborhood_StoneBr  neighborhood_Timber  \
# 459                   0.0                   0.0                  0.0
#
#      neighborhood_Veenker
# 459                   0.0
#
# [1 rows x 39 columns]

# %%
X_test = pd.concat(
    [X_test.drop(columns=['neighborhood']), test_one_hot],
    axis=1
)
X_test.head(1)
# Out:
#      paved_drive  gr_liv_area  overall_qual  garage_area  total_bsmt_sf  \
# 534            2       1728.0             5        504.0         1728.0
#
#      year_built  year_remod_add  mas_vnr_area  fireplaces  bsmtfin_sf_1  ...  \
# 534        1963            1963         336.0           0        1332.0  ...
#
#      neighborhood_NoRidge  neighborhood_NridgHt  neighborhood_OldTown  \
# 534                   0.0                   0.0                   0.0
#
#      neighborhood_SWISU  neighborhood_Sawyer  neighborhood_SawyerW  \
# 534                 0.0                  1.0                   0.0
#
#      neighborhood_Somerst  neighborhood_StoneBr  neighborhood_Timber  \
# 534                   0.0                   0.0                  0.0
#
#      neighborhood_Veenker
# 534                   0.0
#
# [1 rows x 39 columns]

# %% [markdown]
# ### Modeling

# %%
mlr = LinearRegression()

mlr.fit(X_train, y_train)

print('Train set R-squared value: ', mlr.score(X_train, y_train), '\n')
print('Test set R-squared value: ', mlr.score(X_test, y_test), '\n')
print('Intercept: ', mlr.intercept_, '\n')

    # Inefficient code for printing coefficients with corresponding features.
    
            #coefs = mlr.coef_
            #cols = X_train.columns
            #coef_dict = {cols[i]: coefs[i] for i in range(len(X_train.columns))}
            #print('Coefficients')
            #for key in coef_dict:
                #print(key, ': ', coef_dict[key])

pd.DataFrame(zip(X_train.columns, mlr.coef_))
# Out:
# Train set R-squared value:  0.8752067233853532
#
# Test set R-squared value:  0.8838115691876284
#
# Intercept:  -1200899.254877638
#                        0             1
# 0            paved_drive  -2172.320007
# 1            gr_liv_area     50.161779
# 2           overall_qual  13616.392870
# 3            garage_area     37.272308
# 4          total_bsmt_sf     21.955231
# 5             year_built    241.602907
# 6         year_remod_add    351.290569
# 7           mas_vnr_area     37.141319
# 8             fireplaces   6995.422674
# 9           bsmtfin_sf_1     24.748471
# 10           central_air  -3906.758337
# 11  neighborhood_Blmngtn  -4819.305249
# 12  neighborhood_Blueste -21920.085123
# 13   neighborhood_BrDale -31937.246227
# 14  neighborhood_BrkSide   5327.615554
# 15  neighborhood_ClearCr  -1123.607746
# 16  neighborhood_CollgCr  -4098.916771
# 17  neighborhood_Crawfor  14839.879184
# 18  neighborhood_Edwards  -5948.591572
# 19  neighborhood_Gilbert  -5572.134411
# 20   neighborhood_Greens -19060.158216
# 21  neighborhood_GrnHill  89760.995092
# 22   neighborhood_IDOTRR  -4595.559401
# 23  neighborhood_Landmrk -23985.817576
# 24  neighborhood_MeadowV -13995.725403
# 25  neighborhood_Mitchel  -6180.512177
# 26    neighborhood_NAmes  -5329.315257
# 27  neighborhood_NPkVill -19760.956183
# 28   neighborhood_NWAmes -18584.565187
# 29  neighborhood_NoRidge  17642.987483
# 30  neighborhood_NridgHt  29136.223034
# 31  neighborhood_OldTown  -5891.531085
# 32    neighborhood_SWISU  -5592.033487
# 33   neighborhood_Sawyer  -2105.992060
# 34  neighborhood_SawyerW -11039.294592
# 35  neighborhood_Somerst   2086.108130
# 36  neighborhood_StoneBr  54082.994558
# 37   neighborhood_Timber   -487.269264
# 38  neighborhood_Veenker   -848.186046

# %%
X_train.to_csv('../datasets/X_train.csv', index = False)
y_train.to_csv('../datasets/y_train.csv', index = False)
X_test.to_csv('../datasets/X_test.csv', index = False)
y_test.to_csv('../datasets/y_test.csv', index = False)
